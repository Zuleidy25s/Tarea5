# %% [markdown]
# REGRESIÓN LINEAL

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sb
import statsmodels.api as sm

from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge
from sklearn.linear_model import LinearRegression
from sklearn.metrics import classification_report, confusion_matrix
from sympy.solvers import solve
from sympy import Symbol
from sklearn import linear_model
from sklearn.preprocessing import PolynomialFeatures
from sklearn import model_selection
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
Datos = pd.read_csv('./Titanic-Dataset.csv')

# %%
Datos.head(50)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %%
Datos.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
plt.figure(figsize=(6, 3))
sns.boxplot(x=Datos['Age'])
plt.title('Idenficación de Datos faltas y atípicos', fontsize=9)
# Out:
# Text(0.5, 1.0, 'Idenficación de Datos faltas y atípicos')

# %%
print("Cantidad de registros con cero en ID del pasajero: ",Datos['PassengerId'].isnull().sum())
print("Cantidad de registros con cero en Sobrevivió: ",Datos['Survived'].isnull().sum())
print("Cantidad de registros con cero en clase p: ",Datos['Pclass'].isnull().sum())
print("Cantidad de registros con cero en Nombre: ",Datos['Name'].isnull().sum())
print("Cantidad de registros con cero en Sexo: ",Datos['Sex'].isnull().sum())
print("Cantidad de registros con cero en Edad: ",Datos['Age'].isnull().sum())
print("Cantidad de registros con cero en SibSp: ",Datos['SibSp'].isnull().sum())
print("Cantidad de registros con cero en Tostar: ",Datos['Parch'].isnull().sum())
print("Cantidad de registros con cero en Boleto: ",Datos['Ticket'].isnull().sum())
print("Cantidad de registros con cero en Tarifa: ",Datos['Fare'].isnull().sum())
print("Cantidad de registros con cero en Cabina: ",Datos['Cabin'].isnull().sum())
print("Cantidad de registros con cero en Embarcado: ",Datos['Embarked'].isnull().sum())
# Out:
# Cantidad de registros con cero en ID del pasajero:  0
# Cantidad de registros con cero en Sobrevivió:  0
# Cantidad de registros con cero en clase p:  0
# Cantidad de registros con cero en Nombre:  0
# Cantidad de registros con cero en Sexo:  0
# Cantidad de registros con cero en Edad:  177
# Cantidad de registros con cero en SibSp:  0
# Cantidad de registros con cero en Tostar:  0
# Cantidad de registros con cero en Boleto:  0
# Cantidad de registros con cero en Tarifa:  0
# Cantidad de registros con cero en Cabina:  687
# Cantidad de registros con cero en Embarcado:  2

# %%
Datos['Age'].fillna(0, inplace = True)
Datos['Cabin'].fillna(0, inplace = True)
Datos['Embarked'].fillna(0, inplace = True)

# %%
Datos.head(50)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %%
print("Cantidad de registros con cero en ID del pasajero: ",Datos['PassengerId'].isnull().sum())
print("Cantidad de registros con cero en Sobrevivió: ",Datos['Survived'].isnull().sum())
print("Cantidad de registros con cero en clase p: ",Datos['Pclass'].isnull().sum())
print("Cantidad de registros con cero en Nombre: ",Datos['Name'].isnull().sum())
print("Cantidad de registros con cero en Sexo: ",Datos['Sex'].isnull().sum())
print("Cantidad de registros con cero en Edad: ",Datos['Age'].isnull().sum())
print("Cantidad de registros con cero en SibSp: ",Datos['SibSp'].isnull().sum())
print("Cantidad de registros con cero en Tostar: ",Datos['Parch'].isnull().sum())
print("Cantidad de registros con cero en Boleto: ",Datos['Ticket'].isnull().sum())
print("Cantidad de registros con cero en Tarifa: ",Datos['Fare'].isnull().sum())
print("Cantidad de registros con cero en Cabina: ",Datos['Cabin'].isnull().sum())
print("Cantidad de registros con cero en Embarcado: ",Datos['Embarked'].isnull().sum())
# Out:
# Cantidad de registros con cero en ID del pasajero:  0
# Cantidad de registros con cero en Sobrevivió:  0
# Cantidad de registros con cero en clase p:  0
# Cantidad de registros con cero en Nombre:  0
# Cantidad de registros con cero en Sexo:  0
# Cantidad de registros con cero en Edad:  0
# Cantidad de registros con cero en SibSp:  0
# Cantidad de registros con cero en Tostar:  0
# Cantidad de registros con cero en Boleto:  0
# Cantidad de registros con cero en Tarifa:  0
# Cantidad de registros con cero en Cabina:  0
# Cantidad de registros con cero en Embarcado:  0

# %%
plt.figure(figsize=(6, 3))
sns.boxplot(x=Datos['Age'])
plt.title('Idenficación de Datos faltas y atípicos', fontsize=9)
# Out:
# Text(0.5, 1.0, 'Idenficación de Datos faltas y atípicos')

# %%
nivel_minimo=70
nivel_maximo=120
Total_atipicos=((Datos['Age']<nivel_minimo)|(Datos['Age']>nivel_maximo)).sum()
print("El total de datos atípicos es {}".format(Total_atipicos))
# Out:
# El total de datos atípicos es 884

# %%
Datos = Datos[(Datos['Age']<nivel_maximo)&(Datos['Age']>nivel_minimo)]

# %%
Total_atipicos=((Datos['Age']<nivel_minimo)|(Datos['Age']>nivel_maximo)).sum()
print ("El total de datos atípicos es {}".format(Total_atipicos))
# Out:
# El total de datos atípicos es 0

# %%
Datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 96 to 851
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  5 non-null      int64
#  1   Survived     5 non-null      int64
#  2   Pclass       5 non-null      int64
#  3   Name         5 non-null      object
#  4   Sex          5 non-null      object
#  5   Age          5 non-null      float64
#  6   SibSp        5 non-null      int64
#  7   Parch        5 non-null      int64
#  8   Ticket       5 non-null      object
#  9   Fare         5 non-null      float64
#  10  Cabin        5 non-null      object
#  11  Embarked     5 non-null      object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 520.0+ bytes

# %%
Datos['Survived'].value_counts()
# Out:
# Survived
# 0    4
# 1    1
# Name: count, dtype: int64

# %%
Datos = Datos[['Survived', 'Pclass', 'Age', 'PassengerId']]

# %%
X = Datos.drop('Survived',axis=1)
Y = Datos['Survived']

# %%
X.head(50)
# Out:
#      Pclass   Age  PassengerId
# 96        1  71.0           97
# 116       3  70.5          117
# 493       1  71.0          494
# 630       1  80.0          631
# 851       3  74.0          852

# %%
Y.head(50)
# Out:
# 96     0
# 116    0
# 493    0
# 630    1
# 851    0
# Name: Survived, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state= 0)

# %%
print (X_train)
# Out:
#      Pclass   Age  PassengerId
# 116       3  70.5          117
# 630       1  80.0          631
# 851       3  74.0          852

# %%
print (Y_train)
# Out:
# 116    0
# 630    1
# 851    0
# Name: Survived, dtype: int64

# %%
modelo_regresion = LinearRegression()
modelo_regresion.fit (X_train , Y_train)

Prediccion = modelo_regresion.predict(X_test)

# %%
print (Y_test)
# Out:
# 493    0
# 96     0
# Name: Survived, dtype: int64

# %%
print (Prediccion)
# Out:
# [-0.09554871  0.15255901]

# %%
from sklearn import metrics
print('El error absoluto medio del modelo es:', metrics.mean_absolute_error(Y_test, Prediccion))
print('El Error Cuadrático Medio del modelo es:', metrics.mean_squared_error(Y_test, Prediccion))
print('El error cuadratico medio del modelo es:', np.sqrt(metrics.mean_squared_error(Y_test, Prediccion)))
# Out:
# El error absoluto medio del modelo es: 0.12405386188081913
# El Error Cuadrático Medio del modelo es: 0.016201904060724345
# El error cuadratico medio del modelo es: 0.12728670025075026

# %%
fig = plt.figure()
plt.scatter(Y_test, Prediccion)
fig.suptitle('Y_test VS Prediccion', fontsize=20)
plt.xlabel('Y_test', fontsize=18)
plt.ylabel('Prediccion', fontsize=16)
# Out:
# Text(0, 0.5, 'Prediccion')
